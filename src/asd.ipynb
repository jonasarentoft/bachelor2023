# %%
import numpy as np

# %%
bi = np.genfromtxt('bidirectional.txt', delimiter=',')
di = np.genfromtxt('dijkstra.txt', delimiter=',')

# %%
list(set(di) - set(bi))
# Out:
# [nan]

# %%
len(set(bi) - set(di))
# Out:
# 1

# %%
len(set(bi))
# Out:
# 6313

# %%
len(set(di))
# Out:
# 6313

# %%
import collections
print([item for item, count in collections.Counter(bi).items() if count > 1])
# Out:
# [1732967.0]

# %%
bi
# Out:
# array([  44666.,   44668.,   44670., ..., 3779016.,   44240.,      nan])

# %%
set(di) == set(bi)
# Out:
# False

# %%
set(di)
# Out:
# {32768.0,
#  32769.0,
#  32770.0,
#  32771.0,
#  32772.0,
#  32773.0,
#  32774.0,
#  32775.0,
#  32776.0,
#  32777.0,
#  32778.0,
#  32779.0,
#  32780.0,
#  32781.0,
#  32782.0,
#  32783.0,
#  32784.0,
#  32785.0,
#  32786.0,
#  32787.0,
#  983055.0,
#  786453.0,
#  1736719.0,
#  4816917.0,
#  3964952.0,
#  3964953.0,
#  3964954.0,
#  3145748.0,
#  3964956.0,
#  1736732.0,
#  4489246.0,
#  3964959.0,
#  3964960.0,
#  3145761.0,
#  3145762.0,
#  3145763.0,
#  3145755.0,
#  786469.0,
#  3964966.0,
#  3964967.0,
#  3964968.0,
#  4816933.0,
#  3145770.0,
#  4816939.0,
#  3145769.0,
#  3964973.0,
#  3145771.0,
#  3964975.0,
#  3145768.0,
#  3964977.0,
#  3964978.0,
#  3964979.0,
#  32820.0,
#  3964980.0,
#  3964981.0,
#  3964983.0,
#  3964982.0,
#  3964985.0,
#  3964986.0,
#  3964987.0,
#  3964989.0,
#  3964990.0,
#  4816958.0,
#  3964992.0,
#  3964997.0,
#  3964998.0,
#  3964999.0,
#  3965000.0,
#  3965001.0,
#  3965002.0,
#  3965003.0,
#  3965004.0,
#  3965005.0,
#  4816966.0,
# ...

# %%
temp3
# Out:
# [nan]
